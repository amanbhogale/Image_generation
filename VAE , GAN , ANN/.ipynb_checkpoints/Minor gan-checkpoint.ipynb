# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist
from keras.layers import BatchNormalization, Input, Dense, Reshape,Flatten
from keras.layers import ELU, PReLU, LeakyReLU
from keras.layers import LeakyReLU
# Out:
# 2023-11-05 18:02:30.280407: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-05 18:02:30.792076: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-05 18:02:30.794371: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-05 18:02:31.865380: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def build_generator(latent_dim: int):
    
    model = Sequential([
        Dense(128, input_dim=latent_dim),
        LeakyReLU(alpha=0.2),
        BatchNormalization(momentum=0.8),
        Dense(256),
        LeakyReLU(alpha=0.2),
        BatchNormalization(momentum=0.8),
        Dense(512),
        LeakyReLU(alpha=0.2),
        BatchNormalization(momentum=0.8),
        Dense(np.prod((28, 28, 1)), activation='tanh'),
        # reshape to MNIST image size
        Reshape((28, 28, 1))
    ])
    model.summary()
    # the latent input vector z
    z = Input(shape=(latent_dim,))
    generated = model(z)
    # build model from the input and output
    return Model(z, generated)

# %%
def build_discriminator():

    model = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(256),
    LeakyReLU(alpha=0.2),
    Dense(128),
    LeakyReLU(alpha=0.2),
    Dense(1, activation='sigmoid'),
    ], name='discriminator')
    model.summary()
    image = Input(shape=(28, 28, 1))
    output = model(image)
    return Model(image, output)

# %%
def train(generator, discriminator, combined, steps, batch_size):

    # Load the dataset
    (x_train, _), _ = mnist.load_data()
    # Rescale in [-1, 1] interval
    x_train = (x_train.astype(np.float32) - 127.5) / 127.5 
    x_train = np.expand_dims(x_train, axis=-1)
# Discriminator ground truths
    real = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))
    latent_dim = generator.input_shape[1]
    for step in range(steps):
    # Train the discriminator
    # Select a random batch of images
        real_images = x_train[np.random.randint(0, x_train.shape[0], batch_size)]
        # Random batch of noise
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        # Generate a batch of new images
        generated_images = generator.predict(noise)
        # Train the discriminator
        discriminator_real_loss = discriminator.train_on_batch(real_images, real)
        discriminator_fake_loss = discriminator.train_on_batch(generated_images, fake)
        discriminator_loss = 0.5 * np.add(discriminator_real_loss, discriminator_fake_loss)

        # Train the generator
        # random latent vector z
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        # Train the generator
        # Note that we use the "valid" labels for the generated images
        # That's because we try to maximize the discriminator loss
        generator_loss = combined.train_on_batch(noise, real)

        # Display progress
        print("%d [Discriminator loss: %.4f%%, acc.: %.2f%%] [Generator loss: %.4f%%]" %
              (step, discriminator_loss[0], 100 * discriminator_loss[1], generator_loss))

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.models import Model
from keras.optimizers import Adam



def plot_generated_images(generator):
    """
    Display a nxn 2D manifold of digits
    :param generator: the generator
    """
    n = 10
    digit_size = 28
    # big array containing all images
    figure = np.zeros((digit_size * n, digit_size * n))
    latent_dim = generator.input_shape[1]
    # n*n random latent distributions
    noise = np.random.normal(0, 1, (n * n, latent_dim))
    # generate the images
    generated_images = generator.predict(noise)
    # fill the big array with images
    for i in range(n):
        for j in range(n):
            slice_i = slice(i * digit_size, (i + 1) * digit_size)
            slice_j = slice(j * digit_size, (j + 1) * digit_size)
            figure[slice_i, slice_j] = np.reshape(generated_images[i * n + j], (28, 28))
    # plot the results
    plt.figure(figsize=(6, 5))
    plt.axis('off')
    plt.imshow(figure, cmap='Greys_r')
    plt.show()

# %%
if __name__ == '__main__':
    latent_dim = 64

    # Build and compile the discriminator
    discriminator = build_discriminator()
    discriminator.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=0.0002, beta_1=0.5),
        metrics=['accuracy']
    )

    # Build the generator
    generator = build_generator(latent_dim)

    # Generator input z
    z = Input(shape=(latent_dim,))
    generated_image = generator(z)

    # Only train the generator for the combined model
    discriminator.trainable = False

    # The discriminator takes generated image as input and determines validity
    real_or_fake = discriminator(generated_image)

    # Stack the generator and discriminator in a combined model
    # Trains the generator to deceive the discriminator
    combined = Model(z, real_or_fake)
    combined.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=0.0002, beta_1=0.5)
    )

    # train the GAN system
    train(generator=generator,
          discriminator=discriminator,
          combined=combined,
          steps=15000,
          batch_size=128)
    # display some random generated images
    plot_generated_images(generator)
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 256)               200960
#
#  leaky_re_lu (LeakyReLU)     (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 233985 (914.00 KB)
# Trainable params: 233985 (914.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-11-05 18:02:35.666825: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-05 18:02:35.831978: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               8320
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128)               0
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 256)               0
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_5 (Dense)             (None, 512)               131584
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 512)               0
#
#  batch_normalization_2 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_6 (Dense)             (None, 784)               402192
#
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 578704 (2.21 MB)
# Trainable params: 576912 (2.20 MB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 4/4 [==============================] - 0s 2ms/step
# 0 [Discriminator loss: 1.2862%, acc.: 10.94%] [Generator loss: 0.6887%]
# 4/4 [==============================] - 0s 2ms/step
# 1 [Discriminator loss: 0.3389%, acc.: 81.64%] [Generator loss: 0.5445%]
# 4/4 [==============================] - 0s 2ms/step
# 2 [Discriminator loss: 0.3494%, acc.: 73.05%] [Generator loss: 0.5303%]
# 4/4 [==============================] - 0s 2ms/step
# 3 [Discriminator loss: 0.3890%, acc.: 64.45%] [Generator loss: 0.5292%]
# 4/4 [==============================] - 0s 2ms/step
# 4 [Discriminator loss: 0.4222%, acc.: 60.94%] [Generator loss: 0.6006%]
# 4/4 [==============================] - 0s 2ms/step
# 5 [Discriminator loss: 0.3947%, acc.: 63.28%] [Generator loss: 0.7661%]
# 4/4 [==============================] - 0s 2ms/step
# 6 [Discriminator loss: 0.3390%, acc.: 78.12%] [Generator loss: 1.0176%]
# 4/4 [==============================] - 0s 2ms/step
# 7 [Discriminator loss: 0.2501%, acc.: 94.14%] [Generator loss: 1.3444%]
# 4/4 [==============================] - 0s 2ms/step
# 8 [Discriminator loss: 0.1978%, acc.: 96.48%] [Generator loss: 1.6875%]
# 4/4 [==============================] - 0s 2ms/step
# 9 [Discriminator loss: 0.1485%, acc.: 99.22%] [Generator loss: 1.9635%]
# 4/4 [==============================] - 0s 2ms/step
# 10 [Discriminator loss: 0.1228%, acc.: 100.00%] [Generator loss: 2.1978%]
# 4/4 [==============================] - 0s 2ms/step
# 11 [Discriminator loss: 0.1048%, acc.: 100.00%] [Generator loss: 2.3218%]
# 4/4 [==============================] - 0s 2ms/step
# 12 [Discriminator loss: 0.0832%, acc.: 99.61%] [Generator loss: 2.6056%]
# 4/4 [==============================] - 0s 2ms/step
# 13 [Discriminator loss: 0.0708%, acc.: 100.00%] [Generator loss: 2.6067%]
# 4/4 [==============================] - 0s 2ms/step
# 14 [Discriminator loss: 0.0807%, acc.: 100.00%] [Generator loss: 2.7521%]
# 4/4 [==============================] - 0s 2ms/step
# 15 [Discriminator loss: 0.0674%, acc.: 100.00%] [Generator loss: 2.9023%]
# 4/4 [==============================] - 0s 2ms/step
# 16 [Discriminator loss: 0.0588%, acc.: 100.00%] [Generator loss: 2.9784%]
# 4/4 [==============================] - 0s 6ms/step
# 17 [Discriminator loss: 0.0634%, acc.: 100.00%] [Generator loss: 3.0809%]
# 4/4 [==============================] - 0s 3ms/step
# 18 [Discriminator loss: 0.0500%, acc.: 100.00%] [Generator loss: 3.1221%]
# 4/4 [==============================] - 0s 2ms/step
# 19 [Discriminator loss: 0.0486%, acc.: 100.00%] [Generator loss: 3.2556%]
# 4/4 [==============================] - 0s 2ms/step
# 20 [Discriminator loss: 0.0406%, acc.: 100.00%] [Generator loss: 3.2109%]
# 4/4 [==============================] - 0s 2ms/step
# 21 [Discriminator loss: 0.0375%, acc.: 100.00%] [Generator loss: 3.2635%]
# 4/4 [==============================] - 0s 3ms/step
# 22 [Discriminator loss: 0.0435%, acc.: 100.00%] [Generator loss: 3.2468%]
# 4/4 [==============================] - 0s 2ms/step
# 23 [Discriminator loss: 0.0384%, acc.: 100.00%] [Generator loss: 3.2445%]
# 4/4 [==============================] - 0s 2ms/step
# 24 [Discriminator loss: 0.0383%, acc.: 100.00%] [Generator loss: 3.2857%]
# 4/4 [==============================] - 0s 2ms/step
# 25 [Discriminator loss: 0.0374%, acc.: 100.00%] [Generator loss: 3.3457%]
# 4/4 [==============================] - 0s 2ms/step
# 26 [Discriminator loss: 0.0403%, acc.: 100.00%] [Generator loss: 3.4133%]
# 4/4 [==============================] - 0s 2ms/step
# 27 [Discriminator loss: 0.0336%, acc.: 100.00%] [Generator loss: 3.4178%]
# 4/4 [==============================] - 0s 2ms/step
# 28 [Discriminator loss: 0.0427%, acc.: 100.00%] [Generator loss: 3.4951%]
# 4/4 [==============================] - 0s 2ms/step
# 29 [Discriminator loss: 0.0353%, acc.: 100.00%] [Generator loss: 3.5474%]
# 4/4 [==============================] - 0s 2ms/step
# 30 [Discriminator loss: 0.0295%, acc.: 100.00%] [Generator loss: 3.5019%]
# 4/4 [==============================] - 0s 2ms/step
# 31 [Discriminator loss: 0.0377%, acc.: 100.00%] [Generator loss: 3.5668%]
# 4/4 [==============================] - 0s 2ms/step
# 32 [Discriminator loss: 0.0315%, acc.: 100.00%] [Generator loss: 3.5640%]
# 4/4 [==============================] - 0s 2ms/step
# 33 [Discriminator loss: 0.0351%, acc.: 100.00%] [Generator loss: 3.6638%]
# 4/4 [==============================] - 0s 2ms/step
# 34 [Discriminator loss: 0.0426%, acc.: 100.00%] [Generator loss: 3.6736%]
# 4/4 [==============================] - 0s 2ms/step
# 35 [Discriminator loss: 0.0362%, acc.: 100.00%] [Generator loss: 3.8765%]
# 4/4 [==============================] - 0s 2ms/step
# 36 [Discriminator loss: 0.0347%, acc.: 100.00%] [Generator loss: 3.7497%]
# 4/4 [==============================] - 0s 2ms/step
# 37 [Discriminator loss: 0.0314%, acc.: 100.00%] [Generator loss: 3.8097%]
# 4/4 [==============================] - 0s 2ms/step
# 38 [Discriminator loss: 0.0502%, acc.: 99.61%] [Generator loss: 3.8836%]
# 4/4 [==============================] - 0s 2ms/step
# 39 [Discriminator loss: 0.0457%, acc.: 100.00%] [Generator loss: 3.8244%]
# 4/4 [==============================] - 0s 2ms/step
# 40 [Discriminator loss: 0.0408%, acc.: 99.61%] [Generator loss: 4.4140%]
# 4/4 [==============================] - 0s 2ms/step
# 41 [Discriminator loss: 0.1742%, acc.: 92.19%] [Generator loss: 3.8581%]
# 4/4 [==============================] - 0s 2ms/step
# 42 [Discriminator loss: 0.0490%, acc.: 99.61%] [Generator loss: 4.5522%]
# 4/4 [==============================] - 0s 2ms/step
# 43 [Discriminator loss: 0.0314%, acc.: 100.00%] [Generator loss: 4.6412%]
# 4/4 [==============================] - 0s 2ms/step
# 44 [Discriminator loss: 0.2832%, acc.: 87.11%] [Generator loss: 3.1299%]
# 4/4 [==============================] - 0s 2ms/step
# 45 [Discriminator loss: 0.1345%, acc.: 93.36%] [Generator loss: 4.4123%]
# 4/4 [==============================] - 0s 2ms/step
# 46 [Discriminator loss: 0.0224%, acc.: 100.00%] [Generator loss: 4.9905%]
# 4/4 [==============================] - 0s 2ms/step
# 47 [Discriminator loss: 0.4574%, acc.: 79.69%] [Generator loss: 2.7429%]
# 4/4 [==============================] - 0s 3ms/step
# 48 [Discriminator loss: 0.2675%, acc.: 84.77%] [Generator loss: 4.4726%]
# 4/4 [==============================] - 0s 2ms/step
# 49 [Discriminator loss: 0.0301%, acc.: 100.00%] [Generator loss: 5.1552%]
# 4/4 [==============================] - 0s 3ms/step
# 50 [Discriminator loss: 0.0421%, acc.: 100.00%] [Generator loss: 4.3644%]
# 4/4 [==============================] - 0s 2ms/step
# 51 [Discriminator loss: 0.2737%, acc.: 83.20%] [Generator loss: 4.2135%]
# 4/4 [==============================] - 0s 2ms/step
# 52 [Discriminator loss: 0.0550%, acc.: 99.61%] [Generator loss: 5.2379%]
# 4/4 [==============================] - 0s 2ms/step
# 53 [Discriminator loss: 0.9868%, acc.: 65.23%] [Generator loss: 1.8301%]
# 4/4 [==============================] - 0s 2ms/step
# 54 [Discriminator loss: 0.6373%, acc.: 72.27%] [Generator loss: 3.3074%]
# 4/4 [==============================] - 0s 2ms/step
# 55 [Discriminator loss: 0.1964%, acc.: 89.84%] [Generator loss: 4.2493%]
# 4/4 [==============================] - 0s 2ms/step
# 56 [Discriminator loss: 0.0871%, acc.: 98.83%] [Generator loss: 4.2934%]
# 4/4 [==============================] - 0s 2ms/step
# 57 [Discriminator loss: 0.5224%, acc.: 73.05%] [Generator loss: 1.6477%]
# 4/4 [==============================] - 0s 3ms/step
# 58 [Discriminator loss: 0.4150%, acc.: 74.61%] [Generator loss: 3.0147%]
# 4/4 [==============================] - 0s 3ms/step
# 59 [Discriminator loss: 0.0840%, acc.: 98.05%] [Generator loss: 4.0977%]
# 4/4 [==============================] - 0s 2ms/step
# 60 [Discriminator loss: 0.1473%, acc.: 95.31%] [Generator loss: 3.5154%]
# 4/4 [==============================] - 0s 3ms/step
# 61 [Discriminator loss: 0.2133%, acc.: 93.36%] [Generator loss: 3.2565%]
# 4/4 [==============================] - 0s 2ms/step
# 62 [Discriminator loss: 0.3205%, acc.: 83.59%] [Generator loss: 2.9831%]
# 4/4 [==============================] - 0s 2ms/step
# 63 [Discriminator loss: 0.1567%, acc.: 96.48%] [Generator loss: 3.7780%]
# 4/4 [==============================] - 0s 2ms/step
# 64 [Discriminator loss: 1.1758%, acc.: 44.92%] [Generator loss: 0.4398%]
# 4/4 [==============================] - 0s 3ms/step
# 65 [Discriminator loss: 0.6861%, acc.: 60.55%] [Generator loss: 1.2800%]
# 4/4 [==============================] - 0s 3ms/step
# 66 [Discriminator loss: 0.2058%, acc.: 91.02%] [Generator loss: 2.9868%]
# 4/4 [==============================] - 0s 3ms/step
# 67 [Discriminator loss: 0.1991%, acc.: 97.66%] [Generator loss: 2.9225%]
# 4/4 [==============================] - 0s 3ms/step
# 68 [Discriminator loss: 0.2356%, acc.: 94.53%] [Generator loss: 2.5647%]
# 4/4 [==============================] - 0s 2ms/step
# 69 [Discriminator loss: 0.2179%, acc.: 94.53%] [Generator loss: 3.2897%]
# 4/4 [==============================] - 0s 2ms/step
# 70 [Discriminator loss: 0.6954%, acc.: 57.81%] [Generator loss: 1.0627%]
# 4/4 [==============================] - 0s 2ms/step
# 71 [Discriminator loss: 0.2987%, acc.: 82.81%] [Generator loss: 3.2334%]
# 4/4 [==============================] - 0s 2ms/step
# 72 [Discriminator loss: 0.6521%, acc.: 58.98%] [Generator loss: 1.4847%]
# 4/4 [==============================] - 0s 3ms/step
# 73 [Discriminator loss: 0.2266%, acc.: 88.67%] [Generator loss: 3.7437%]
# 4/4 [==============================] - 0s 2ms/step
# 74 [Discriminator loss: 1.0820%, acc.: 33.59%] [Generator loss: 0.4710%]
# 4/4 [==============================] - 0s 2ms/step
# 75 [Discriminator loss: 0.5410%, acc.: 57.03%] [Generator loss: 1.6668%]
# 4/4 [==============================] - 0s 3ms/step
# 76 [Discriminator loss: 0.1861%, acc.: 98.83%] [Generator loss: 3.5520%]
# 4/4 [==============================] - 0s 3ms/step
# 77 [Discriminator loss: 1.7091%, acc.: 2.73%] [Generator loss: 0.2208%]
# 4/4 [==============================] - 0s 2ms/step
# 78 [Discriminator loss: 0.9219%, acc.: 50.00%] [Generator loss: 0.6416%]
# 4/4 [==============================] - 0s 2ms/step
# 79 [Discriminator loss: 0.3327%, acc.: 78.91%] [Generator loss: 2.2429%]
# 4/4 [==============================] - 0s 2ms/step
# 80 [Discriminator loss: 0.9474%, acc.: 17.19%] [Generator loss: 0.5113%]
# 4/4 [==============================] - 0s 2ms/step
# 81 [Discriminator loss: 0.5690%, acc.: 50.39%] [Generator loss: 0.7573%]
# 4/4 [==============================] - 0s 3ms/step
# 82 [Discriminator loss: 0.3720%, acc.: 77.34%] [Generator loss: 1.4518%]
# 4/4 [==============================] - 0s 2ms/step
# 83 [Discriminator loss: 0.5013%, acc.: 79.69%] [Generator loss: 1.2207%]
# 4/4 [==============================] - 0s 2ms/step
# 84 [Discriminator loss: 0.4312%, acc.: 80.86%] [Generator loss: 1.4140%]
# 4/4 [==============================] - 0s 2ms/step
# 85 [Discriminator loss: 0.5503%, acc.: 62.11%] [Generator loss: 1.0985%]
# 4/4 [==============================] - 0s 4ms/step
# 86 [Discriminator loss: 0.3980%, acc.: 79.69%] [Generator loss: 1.7420%]
# 4/4 [==============================] - 0s 3ms/step
# 87 [Discriminator loss: 0.8606%, acc.: 41.02%] [Generator loss: 0.4533%]
# 4/4 [==============================] - 0s 2ms/step
# 88 [Discriminator loss: 0.5901%, acc.: 50.78%] [Generator loss: 0.6966%]
# 4/4 [==============================] - 0s 5ms/step
# 89 [Discriminator loss: 0.4332%, acc.: 67.97%] [Generator loss: 1.1324%]
# 4/4 [==============================] - 0s 2ms/step
# 90 [Discriminator loss: 0.5890%, acc.: 64.06%] [Generator loss: 0.8642%]
# 4/4 [==============================] - 0s 3ms/step
# 91 [Discriminator loss: 0.4799%, acc.: 66.02%] [Generator loss: 1.1602%]
# 4/4 [==============================] - 0s 4ms/step
# 92 [Discriminator loss: 0.5372%, acc.: 64.45%] [Generator loss: 1.1098%]
# 4/4 [==============================] - 0s 2ms/step
# 93 [Discriminator loss: 0.5079%, acc.: 64.06%] [Generator loss: 1.2909%]
# 4/4 [==============================] - 0s 4ms/step
# 94 [Discriminator loss: 0.6020%, acc.: 54.69%] [Generator loss: 0.8975%]
# 4/4 [==============================] - 0s 2ms/step
# 95 [Discriminator loss: 0.4776%, acc.: 65.62%] [Generator loss: 1.4324%]
# 4/4 [==============================] - 0s 3ms/step
# 96 [Discriminator loss: 0.8392%, acc.: 45.31%] [Generator loss: 0.4627%]
# 4/4 [==============================] - 0s 5ms/step
# 97 [Discriminator loss: 0.5932%, acc.: 50.78%] [Generator loss: 0.7439%]
# 4/4 [==============================] - 0s 2ms/step
# 98 [Discriminator loss: 0.5064%, acc.: 62.50%] [Generator loss: 1.1284%]
# 4/4 [==============================] - 0s 2ms/step
# 99 [Discriminator loss: 0.6881%, acc.: 51.95%] [Generator loss: 0.6920%]
# 4/4 [==============================] - 0s 4ms/step
# 100 [Discriminator loss: 0.5070%, acc.: 58.20%] [Generator loss: 1.0399%]
# 4/4 [==============================] - 0s 2ms/step
# 101 [Discriminator loss: 0.5673%, acc.: 59.38%] [Generator loss: 1.0557%]
# 4/4 [==============================] - 0s 2ms/step
# 102 [Discriminator loss: 0.5636%, acc.: 60.94%] [Generator loss: 1.1165%]
# 4/4 [==============================] - 0s 2ms/step
# 103 [Discriminator loss: 0.5555%, acc.: 62.89%] [Generator loss: 1.1526%]
# 4/4 [==============================] - 0s 3ms/step
# 104 [Discriminator loss: 0.5962%, acc.: 56.25%] [Generator loss: 0.9033%]
# 4/4 [==============================] - 0s 2ms/step
# 105 [Discriminator loss: 0.5338%, acc.: 61.72%] [Generator loss: 1.2471%]
# 4/4 [==============================] - 0s 2ms/step
# 106 [Discriminator loss: 0.6960%, acc.: 50.00%] [Generator loss: 0.6811%]
# 4/4 [==============================] - 0s 2ms/step
# 107 [Discriminator loss: 0.5386%, acc.: 53.91%] [Generator loss: 0.9693%]
# 4/4 [==============================] - 0s 3ms/step
# 108 [Discriminator loss: 0.6217%, acc.: 53.12%] [Generator loss: 0.8380%]
# 4/4 [==============================] - 0s 2ms/step
# 109 [Discriminator loss: 0.5642%, acc.: 57.42%] [Generator loss: 1.0556%]
# 4/4 [==============================] - 0s 2ms/step
# 110 [Discriminator loss: 0.6280%, acc.: 55.08%] [Generator loss: 0.8726%]
# 4/4 [==============================] - 0s 2ms/step
# 111 [Discriminator loss: 0.5858%, acc.: 56.25%] [Generator loss: 1.0149%]
# 4/4 [==============================] - 0s 2ms/step
# 112 [Discriminator loss: 0.5864%, acc.: 56.64%] [Generator loss: 1.0586%]
# 4/4 [==============================] - 0s 2ms/step
# 113 [Discriminator loss: 0.6107%, acc.: 54.69%] [Generator loss: 0.9213%]
# 4/4 [==============================] - 0s 2ms/step
# 114 [Discriminator loss: 0.6020%, acc.: 52.34%] [Generator loss: 1.0337%]
# 4/4 [==============================] - 0s 2ms/step
# 115 [Discriminator loss: 0.6278%, acc.: 51.56%] [Generator loss: 0.8956%]
# 4/4 [==============================] - 0s 2ms/step
# 116 [Discriminator loss: 0.6195%, acc.: 51.17%] [Generator loss: 0.8770%]
# 4/4 [==============================] - 0s 3ms/step
# 117 [Discriminator loss: 0.5981%, acc.: 55.08%] [Generator loss: 0.9026%]
# 4/4 [==============================] - 0s 2ms/step
# 118 [Discriminator loss: 0.6233%, acc.: 51.17%] [Generator loss: 0.8206%]
# 4/4 [==============================] - 0s 2ms/step
# 119 [Discriminator loss: 0.5916%, acc.: 56.25%] [Generator loss: 0.9778%]
# 4/4 [==============================] - 0s 2ms/step
# 120 [Discriminator loss: 0.6488%, acc.: 50.00%] [Generator loss: 0.7842%]
# 4/4 [==============================] - 0s 2ms/step
# 121 [Discriminator loss: 0.5925%, acc.: 53.91%] [Generator loss: 0.9996%]
# 4/4 [==============================] - 0s 2ms/step
# 122 [Discriminator loss: 0.6790%, acc.: 50.00%] [Generator loss: 0.7295%]
# 4/4 [==============================] - 0s 4ms/step
# 123 [Discriminator loss: 0.6042%, acc.: 51.17%] [Generator loss: 0.8415%]
# 4/4 [==============================] - 0s 2ms/step
# 124 [Discriminator loss: 0.6389%, acc.: 50.78%] [Generator loss: 0.8093%]
# 4/4 [==============================] - 0s 2ms/step
# 125 [Discriminator loss: 0.6204%, acc.: 53.12%] [Generator loss: 0.7734%]
# 4/4 [==============================] - 0s 2ms/step
# 126 [Discriminator loss: 0.5992%, acc.: 54.69%] [Generator loss: 0.9003%]
# 4/4 [==============================] - 0s 2ms/step
# 127 [Discriminator loss: 0.6563%, acc.: 50.78%] [Generator loss: 0.7370%]
# 4/4 [==============================] - 0s 5ms/step
# 128 [Discriminator loss: 0.6274%, acc.: 51.17%] [Generator loss: 0.7901%]
# 4/4 [==============================] - 0s 2ms/step
# 129 [Discriminator loss: 0.6392%, acc.: 50.78%] [Generator loss: 0.8232%]
# 4/4 [==============================] - 0s 2ms/step
# 130 [Discriminator loss: 0.6465%, acc.: 51.95%] [Generator loss: 0.7907%]
# 4/4 [==============================] - 0s 2ms/step
# 131 [Discriminator loss: 0.6379%, acc.: 50.78%] [Generator loss: 0.7780%]
# 4/4 [==============================] - 0s 2ms/step
# 132 [Discriminator loss: 0.6468%, acc.: 49.61%] [Generator loss: 0.7730%]
# 4/4 [==============================] - 0s 2ms/step
# 133 [Discriminator loss: 0.6265%, acc.: 50.78%] [Generator loss: 0.8043%]
# 4/4 [==============================] - 0s 3ms/step
# 134 [Discriminator loss: 0.6503%, acc.: 50.78%] [Generator loss: 0.7559%]
# 4/4 [==============================] - 0s 4ms/step
# 135 [Discriminator loss: 0.6317%, acc.: 50.00%] [Generator loss: 0.7611%]
# 4/4 [==============================] - 0s 2ms/step
# 136 [Discriminator loss: 0.6497%, acc.: 50.00%] [Generator loss: 0.7627%]
# 4/4 [==============================] - 0s 2ms/step
# 137 [Discriminator loss: 0.6389%, acc.: 52.73%] [Generator loss: 0.7722%]
# 4/4 [==============================] - 0s 2ms/step
# 138 [Discriminator loss: 0.6511%, acc.: 53.12%] [Generator loss: 0.7668%]
# 4/4 [==============================] - 0s 2ms/step
# 139 [Discriminator loss: 0.6503%, acc.: 50.39%] [Generator loss: 0.7386%]
# 4/4 [==============================] - 0s 2ms/step
# 140 [Discriminator loss: 0.6481%, acc.: 50.00%] [Generator loss: 0.6957%]
# 4/4 [==============================] - 0s 4ms/step
# 141 [Discriminator loss: 0.6392%, acc.: 50.00%] [Generator loss: 0.7215%]
# 4/4 [==============================] - 0s 5ms/step
# 142 [Discriminator loss: 0.6364%, acc.: 51.56%] [Generator loss: 0.7318%]
# 4/4 [==============================] - 0s 2ms/step
# 143 [Discriminator loss: 0.6379%, acc.: 50.78%] [Generator loss: 0.7411%]
# 4/4 [==============================] - 0s 2ms/step
# 144 [Discriminator loss: 0.6452%, acc.: 50.78%] [Generator loss: 0.7259%]
# 4/4 [==============================] - 0s 2ms/step
# 145 [Discriminator loss: 0.6506%, acc.: 50.39%] [Generator loss: 0.7113%]
# 4/4 [==============================] - 0s 2ms/step
# 146 [Discriminator loss: 0.6414%, acc.: 50.78%] [Generator loss: 0.7095%]
# 4/4 [==============================] - 0s 2ms/step
# 147 [Discriminator loss: 0.6295%, acc.: 51.17%] [Generator loss: 0.7160%]
# 4/4 [==============================] - 0s 2ms/step
# 148 [Discriminator loss: 0.6512%, acc.: 50.78%] [Generator loss: 0.7341%]
# 4/4 [==============================] - 0s 1ms/step
# 149 [Discriminator loss: 0.6494%, acc.: 51.95%] [Generator loss: 0.7108%]
# 4/4 [==============================] - 0s 2ms/step
# 150 [Discriminator loss: 0.6259%, acc.: 50.78%] [Generator loss: 0.7463%]
# 4/4 [==============================] - 0s 4ms/step
# 151 [Discriminator loss: 0.6558%, acc.: 50.78%] [Generator loss: 0.7314%]
# 4/4 [==============================] - 0s 2ms/step
# 152 [Discriminator loss: 0.6382%, acc.: 51.17%] [Generator loss: 0.7182%]
# 4/4 [==============================] - 0s 3ms/step
# 153 [Discriminator loss: 0.6391%, acc.: 51.56%] [Generator loss: 0.7178%]
# 4/4 [==============================] - 0s 3ms/step
# 154 [Discriminator loss: 0.6424%, acc.: 49.61%] [Generator loss: 0.7224%]
# 4/4 [==============================] - 0s 2ms/step
# 155 [Discriminator loss: 0.6284%, acc.: 51.95%] [Generator loss: 0.7300%]
# 4/4 [==============================] - 0s 2ms/step
# 156 [Discriminator loss: 0.6426%, acc.: 50.78%] [Generator loss: 0.7436%]
# 4/4 [==============================] - 0s 4ms/step
# 157 [Discriminator loss: 0.6375%, acc.: 52.73%] [Generator loss: 0.7340%]
# 4/4 [==============================] - 0s 3ms/step
# 158 [Discriminator loss: 0.6499%, acc.: 51.95%] [Generator loss: 0.7251%]
# 4/4 [==============================] - 0s 2ms/step
# 159 [Discriminator loss: 0.6428%, acc.: 51.56%] [Generator loss: 0.7251%]
# 4/4 [==============================] - 0s 2ms/step
# 160 [Discriminator loss: 0.6480%, acc.: 53.52%] [Generator loss: 0.7111%]
# 4/4 [==============================] - 0s 5ms/step
# 161 [Discriminator loss: 0.6444%, acc.: 51.17%] [Generator loss: 0.7391%]
# 4/4 [==============================] - 0s 4ms/step
# 162 [Discriminator loss: 0.6620%, acc.: 53.52%] [Generator loss: 0.7574%]
# 4/4 [==============================] - 0s 5ms/step
# 163 [Discriminator loss: 0.6663%, acc.: 51.56%] [Generator loss: 0.7103%]
# 4/4 [==============================] - 0s 4ms/step
# 164 [Discriminator loss: 0.6425%, acc.: 51.56%] [Generator loss: 0.7101%]
# 4/4 [==============================] - 0s 5ms/step
# 165 [Discriminator loss: 0.6722%, acc.: 51.56%] [Generator loss: 0.7252%]
# 4/4 [==============================] - 0s 5ms/step
# 166 [Discriminator loss: 0.6580%, acc.: 53.12%] [Generator loss: 0.7351%]
# 4/4 [==============================] - 0s 2ms/step
# 167 [Discriminator loss: 0.6595%, acc.: 51.17%] [Generator loss: 0.7357%]
# 4/4 [==============================] - 0s 2ms/step
# 168 [Discriminator loss: 0.6665%, acc.: 52.73%] [Generator loss: 0.7289%]
# 4/4 [==============================] - 0s 2ms/step
# 169 [Discriminator loss: 0.6550%, acc.: 53.91%] [Generator loss: 0.7590%]
# 4/4 [==============================] - 0s 2ms/step
# 170 [Discriminator loss: 0.6749%, acc.: 50.78%] [Generator loss: 0.7664%]
# 4/4 [==============================] - 0s 2ms/step
# 171 [Discriminator loss: 0.6854%, acc.: 48.05%] [Generator loss: 0.7632%]
# 4/4 [==============================] - 0s 2ms/step
# 172 [Discriminator loss: 0.7038%, acc.: 51.17%] [Generator loss: 0.7102%]
# 4/4 [==============================] - 0s 2ms/step
# 173 [Discriminator loss: 0.6736%, acc.: 50.00%] [Generator loss: 0.7650%]
# 4/4 [==============================] - 0s 2ms/step
# 174 [Discriminator loss: 0.6694%, acc.: 51.56%] [Generator loss: 0.7591%]
# 4/4 [==============================] - 0s 2ms/step
# 175 [Discriminator loss: 0.6672%, acc.: 51.56%] [Generator loss: 0.7895%]
# 4/4 [==============================] - 0s 4ms/step
# 176 [Discriminator loss: 0.6665%, acc.: 49.22%] [Generator loss: 0.7421%]
# 4/4 [==============================] - 0s 3ms/step
# 177 [Discriminator loss: 0.6530%, acc.: 54.30%] [Generator loss: 0.7482%]
# 4/4 [==============================] - 0s 3ms/step
# 178 [Discriminator loss: 0.6616%, acc.: 49.61%] [Generator loss: 0.7699%]
# 4/4 [==============================] - 0s 2ms/step
# 179 [Discriminator loss: 0.6501%, acc.: 50.78%] [Generator loss: 0.7395%]
# 4/4 [==============================] - 0s 1ms/step
# 180 [Discriminator loss: 0.6433%, acc.: 52.73%] [Generator loss: 0.7818%]
# 4/4 [==============================] - 0s 2ms/step
# 181 [Discriminator loss: 0.6374%, acc.: 53.12%] [Generator loss: 0.7698%]
# 4/4 [==============================] - 0s 2ms/step
# 182 [Discriminator loss: 0.6327%, acc.: 57.03%] [Generator loss: 0.7737%]
# 4/4 [==============================] - 0s 2ms/step
# 183 [Discriminator loss: 0.6311%, acc.: 58.20%] [Generator loss: 0.7807%]
# 4/4 [==============================] - 0s 2ms/step
# 184 [Discriminator loss: 0.6373%, acc.: 56.25%] [Generator loss: 0.7959%]
# 4/4 [==============================] - 0s 3ms/step
# 185 [Discriminator loss: 0.6255%, acc.: 58.59%] [Generator loss: 0.8050%]
# 4/4 [==============================] - 0s 2ms/step
# 186 [Discriminator loss: 0.6316%, acc.: 59.38%] [Generator loss: 0.7979%]
# 4/4 [==============================] - 0s 2ms/step
# 187 [Discriminator loss: 0.6426%, acc.: 51.95%] [Generator loss: 0.8412%]
# 4/4 [==============================] - 0s 2ms/step
# 188 [Discriminator loss: 0.6367%, acc.: 67.97%] [Generator loss: 0.8363%]
# 4/4 [==============================] - 0s 2ms/step
# 189 [Discriminator loss: 0.6522%, acc.: 60.16%] [Generator loss: 0.7831%]
# 4/4 [==============================] - 0s 2ms/step
# 190 [Discriminator loss: 0.6456%, acc.: 51.95%] [Generator loss: 0.8051%]
# 4/4 [==============================] - 0s 2ms/step
# 191 [Discriminator loss: 0.6107%, acc.: 66.80%] [Generator loss: 0.8349%]
# 4/4 [==============================] - 0s 2ms/step
# 192 [Discriminator loss: 0.6158%, acc.: 70.31%] [Generator loss: 0.8232%]
# 4/4 [==============================] - 0s 2ms/step
# 193 [Discriminator loss: 0.6144%, acc.: 66.02%] [Generator loss: 0.8296%]
# 4/4 [==============================] - 0s 2ms/step
# 194 [Discriminator loss: 0.6108%, acc.: 65.23%] [Generator loss: 0.8331%]
# 4/4 [==============================] - 0s 3ms/step
# 195 [Discriminator loss: 0.6227%, acc.: 72.27%] [Generator loss: 0.8420%]
# 4/4 [==============================] - 0s 2ms/step
# 196 [Discriminator loss: 0.6459%, acc.: 66.80%] [Generator loss: 0.8895%]
# 4/4 [==============================] - 0s 2ms/step
# 197 [Discriminator loss: 0.6096%, acc.: 78.12%] [Generator loss: 0.8496%]
# 4/4 [==============================] - 0s 2ms/step
# 198 [Discriminator loss: 0.6477%, acc.: 63.28%] [Generator loss: 0.8725%]
# 4/4 [==============================] - 0s 2ms/step
# 199 [Discriminator loss: 0.6344%, acc.: 60.94%] [Generator loss: 0.8406%]
# 4/4 [==============================] - 0s 4ms/step
# 200 [Discriminator loss: 0.6350%, acc.: 58.59%] [Generator loss: 0.8644%]
# 4/4 [==============================] - 0s 5ms/step
# 201 [Discriminator loss: 0.6260%, acc.: 67.58%] [Generator loss: 0.8488%]
# 4/4 [==============================] - 0s 5ms/step
# 202 [Discriminator loss: 0.6145%, acc.: 66.02%] [Generator loss: 0.9284%]
# 4/4 [==============================] - 0s 5ms/step
# 203 [Discriminator loss: 0.6563%, acc.: 62.50%] [Generator loss: 0.8351%]
# 4/4 [==============================] - 0s 2ms/step
# 204 [Discriminator loss: 0.6532%, acc.: 54.69%] [Generator loss: 0.8732%]
# 4/4 [==============================] - 0s 2ms/step
# 205 [Discriminator loss: 0.6652%, acc.: 58.20%] [Generator loss: 0.8625%]
# 4/4 [==============================] - 0s 2ms/step
# 206 [Discriminator loss: 0.6520%, acc.: 55.86%] [Generator loss: 0.8661%]
# 4/4 [==============================] - 0s 2ms/step
# 207 [Discriminator loss: 0.6616%, acc.: 55.47%] [Generator loss: 0.8179%]
# 4/4 [==============================] - 0s 2ms/step
# 208 [Discriminator loss: 0.6774%, acc.: 58.59%] [Generator loss: 0.9736%]
# 4/4 [==============================] - 0s 2ms/step
# 209 [Discriminator loss: 0.6998%, acc.: 54.69%] [Generator loss: 0.8692%]
# 4/4 [==============================] - 0s 2ms/step
# 210 [Discriminator loss: 0.6971%, acc.: 50.00%] [Generator loss: 0.8144%]
# 4/4 [==============================] - 0s 2ms/step
# 211 [Discriminator loss: 0.7118%, acc.: 50.78%] [Generator loss: 0.8244%]
# 4/4 [==============================] - 0s 2ms/step
# 212 [Discriminator loss: 0.6776%, acc.: 53.52%] [Generator loss: 0.8262%]
# 4/4 [==============================] - 0s 2ms/step
# 213 [Discriminator loss: 0.6950%, acc.: 49.22%] [Generator loss: 0.7993%]
# 4/4 [==============================] - 0s 2ms/step
# 214 [Discriminator loss: 0.6682%, acc.: 53.91%] [Generator loss: 0.7828%]
# 4/4 [==============================] - 0s 2ms/step
# 215 [Discriminator loss: 0.6526%, acc.: 56.64%] [Generator loss: 0.8915%]
# 4/4 [==============================] - 0s 2ms/step
# 216 [Discriminator loss: 0.6841%, acc.: 50.00%] [Generator loss: 0.7955%]
# 4/4 [==============================] - 0s 2ms/step
# 217 [Discriminator loss: 0.6649%, acc.: 54.30%] [Generator loss: 0.8346%]
# 4/4 [==============================] - 0s 2ms/step
# 218 [Discriminator loss: 0.6655%, acc.: 59.38%] [Generator loss: 0.8017%]
# 4/4 [==============================] - 0s 2ms/step
# 219 [Discriminator loss: 0.6807%, acc.: 59.77%] [Generator loss: 0.8098%]
# 4/4 [==============================] - 0s 2ms/step
# 220 [Discriminator loss: 0.6570%, acc.: 60.94%] [Generator loss: 0.8333%]
# 4/4 [==============================] - 0s 2ms/step
# 221 [Discriminator loss: 0.6837%, acc.: 53.91%] [Generator loss: 0.7942%]
# 4/4 [==============================] - 0s 2ms/step
# 222 [Discriminator loss: 0.6648%, acc.: 57.42%] [Generator loss: 0.8384%]
# 4/4 [==============================] - 0s 2ms/step
# 223 [Discriminator loss: 0.6672%, acc.: 55.86%] [Generator loss: 0.7825%]
# 4/4 [==============================] - 0s 2ms/step
# 224 [Discriminator loss: 0.6509%, acc.: 62.50%] [Generator loss: 0.7964%]
# 4/4 [==============================] - 0s 2ms/step
# 225 [Discriminator loss: 0.6539%, acc.: 59.38%] [Generator loss: 0.7833%]
# 4/4 [==============================] - 0s 3ms/step
# 226 [Discriminator loss: 0.6413%, acc.: 61.72%] [Generator loss: 0.8076%]
# 4/4 [==============================] - 0s 3ms/step
# 227 [Discriminator loss: 0.6577%, acc.: 60.55%] [Generator loss: 0.8145%]
# 4/4 [==============================] - 0s 3ms/step
# 228 [Discriminator loss: 0.6390%, acc.: 64.06%] [Generator loss: 0.8054%]
# 4/4 [==============================] - 0s 3ms/step
# 229 [Discriminator loss: 0.6494%, acc.: 66.02%] [Generator loss: 0.8037%]
# 4/4 [==============================] - 0s 3ms/step
# 230 [Discriminator loss: 0.6594%, acc.: 66.02%] [Generator loss: 0.8169%]
# 4/4 [==============================] - 0s 2ms/step
# 231 [Discriminator loss: 0.6279%, acc.: 66.02%] [Generator loss: 0.8142%]
# 4/4 [==============================] - 0s 2ms/step
# 232 [Discriminator loss: 0.6447%, acc.: 61.33%] [Generator loss: 0.8318%]
# 4/4 [==============================] - 0s 2ms/step
# 233 [Discriminator loss: 0.6413%, acc.: 62.89%] [Generator loss: 0.8328%]
# 4/4 [==============================] - 0s 2ms/step
# 234 [Discriminator loss: 0.6403%, acc.: 64.84%] [Generator loss: 0.8198%]
# 4/4 [==============================] - 0s 2ms/step
# 235 [Discriminator loss: 0.6224%, acc.: 70.70%] [Generator loss: 0.8244%]
# 4/4 [==============================] - 0s 2ms/step
# 236 [Discriminator loss: 0.6522%, acc.: 62.50%] [Generator loss: 0.8430%]
# 4/4 [==============================] - 0s 4ms/step
# 237 [Discriminator loss: 0.6388%, acc.: 66.80%] [Generator loss: 0.8197%]
# 4/4 [==============================] - 0s 4ms/step
# 238 [Discriminator loss: 0.6187%, acc.: 68.75%] [Generator loss: 0.8327%]
# 4/4 [==============================] - 0s 2ms/step
# 239 [Discriminator loss: 0.6438%, acc.: 64.84%] [Generator loss: 0.8241%]
# 4/4 [==============================] - 0s 5ms/step
# 240 [Discriminator loss: 0.6564%, acc.: 64.84%] [Generator loss: 0.8358%]
# 4/4 [==============================] - 0s 3ms/step
# 241 [Discriminator loss: 0.6520%, acc.: 60.16%] [Generator loss: 0.8174%]
# 4/4 [==============================] - 0s 2ms/step
# 242 [Discriminator loss: 0.6655%, acc.: 58.20%] [Generator loss: 0.8595%]
# 4/4 [==============================] - 0s 2ms/step
# 243 [Discriminator loss: 0.6669%, acc.: 57.42%] [Generator loss: 0.7923%]
# 4/4 [==============================] - 0s 4ms/step
# 244 [Discriminator loss: 0.6512%, acc.: 61.72%] [Generator loss: 0.8454%]
# 4/4 [==============================] - 0s 2ms/step
# 245 [Discriminator loss: 0.6610%, acc.: 65.62%] [Generator loss: 0.8070%]
# 4/4 [==============================] - 0s 4ms/step
# 246 [Discriminator loss: 0.6509%, acc.: 60.94%] [Generator loss: 0.8149%]
# 4/4 [==============================] - 0s 4ms/step
# 247 [Discriminator loss: 0.6619%, acc.: 60.94%] [Generator loss: 0.8479%]
# 4/4 [==============================] - 0s 3ms/step
# 248 [Discriminator loss: 0.6587%, acc.: 64.45%] [Generator loss: 0.8086%]
# 4/4 [==============================] - 0s 2ms/step
# 249 [Discriminator loss: 0.6400%, acc.: 65.23%] [Generator loss: 0.8506%]
# 4/4 [==============================] - 0s 2ms/step
# 250 [Discriminator loss: 0.6589%, acc.: 68.36%] [Generator loss: 0.8272%]
# 4/4 [==============================] - 0s 3ms/step
# 251 [Discriminator loss: 0.6493%, acc.: 67.58%] [Generator loss: 0.8019%]
# 4/4 [==============================] - 0s 2ms/step
# 252 [Discriminator loss: 0.6325%, acc.: 62.50%] [Generator loss: 0.8339%]
# 4/4 [==============================] - 0s 2ms/step
# 253 [Discriminator loss: 0.6351%, acc.: 67.58%] [Generator loss: 0.8439%]
# 4/4 [==============================] - 0s 2ms/step
# 254 [Discriminator loss: 0.6638%, acc.: 62.50%] [Generator loss: 0.8348%]
# 4/4 [==============================] - 0s 2ms/step
# 255 [Discriminator loss: 0.6309%, acc.: 65.23%] [Generator loss: 0.8486%]
# 4/4 [==============================] - 0s 3ms/step
# 256 [Discriminator loss: 0.6576%, acc.: 65.62%] [Generator loss: 0.8515%]
# 4/4 [==============================] - 0s 2ms/step
# 257 [Discriminator loss: 0.6424%, acc.: 64.84%] [Generator loss: 0.8148%]
# 4/4 [==============================] - 0s 2ms/step
# 258 [Discriminator loss: 0.6448%, acc.: 62.50%] [Generator loss: 0.8318%]
# 4/4 [==============================] - 0s 2ms/step
# 259 [Discriminator loss: 0.6261%, acc.: 69.14%] [Generator loss: 0.8286%]
# 4/4 [==============================] - 0s 2ms/step
# 260 [Discriminator loss: 0.6382%, acc.: 63.28%] [Generator loss: 0.8323%]
# 4/4 [==============================] - 0s 2ms/step
# 261 [Discriminator loss: 0.6262%, acc.: 66.41%] [Generator loss: 0.8619%]
# 4/4 [==============================] - 0s 2ms/step
# 262 [Discriminator loss: 0.6384%, acc.: 72.66%] [Generator loss: 0.8340%]
# 4/4 [==============================] - 0s 2ms/step
# 263 [Discriminator loss: 0.6381%, acc.: 66.41%] [Generator loss: 0.8888%]
# 4/4 [==============================] - 0s 2ms/step
# 264 [Discriminator loss: 0.6526%, acc.: 67.58%] [Generator loss: 0.8236%]
# 4/4 [==============================] - 0s 2ms/step
# 265 [Discriminator loss: 0.6417%, acc.: 64.06%] [Generator loss: 0.8460%]
# 4/4 [==============================] - 0s 2ms/step
# 266 [Discriminator loss: 0.6347%, acc.: 67.19%] [Generator loss: 0.8573%]
# 4/4 [==============================] - 0s 2ms/step
# 267 [Discriminator loss: 0.6148%, acc.: 70.70%] [Generator loss: 0.8665%]
# 4/4 [==============================] - 0s 2ms/step
# 268 [Discriminator loss: 0.6394%, acc.: 62.11%] [Generator loss: 0.8481%]
# 4/4 [==============================] - 0s 2ms/step
# 269 [Discriminator loss: 0.6218%, acc.: 67.19%] [Generator loss: 0.9225%]
# 4/4 [==============================] - 0s 3ms/step
# 270 [Discriminator loss: 0.6470%, acc.: 64.45%] [Generator loss: 0.8796%]
# 4/4 [==============================] - 0s 2ms/step
# 271 [Discriminator loss: 0.6223%, acc.: 65.62%] [Generator loss: 0.8610%]
# 4/4 [==============================] - 0s 2ms/step
# 272 [Discriminator loss: 0.6208%, acc.: 68.75%] [Generator loss: 0.9083%]
# 4/4 [==============================] - 0s 2ms/step
# 273 [Discriminator loss: 0.6496%, acc.: 61.72%] [Generator loss: 0.8803%]
# 4/4 [==============================] - 0s 2ms/step
# 274 [Discriminator loss: 0.6165%, acc.: 67.97%] [Generator loss: 0.9274%]
# 4/4 [==============================] - 0s 2ms/step
# 275 [Discriminator loss: 0.6501%, acc.: 62.11%] [Generator loss: 0.8669%]
# 4/4 [==============================] - 0s 2ms/step
# 276 [Discriminator loss: 0.5826%, acc.: 76.95%] [Generator loss: 0.9068%]
# 4/4 [==============================] - 0s 4ms/step
# 277 [Discriminator loss: 0.6357%, acc.: 66.41%] [Generator loss: 0.9516%]
# 4/4 [==============================] - 0s 2ms/step
# 278 [Discriminator loss: 0.5965%, acc.: 76.56%] [Generator loss: 0.9162%]
# 4/4 [==============================] - 0s 3ms/step
# 279 [Discriminator loss: 0.6178%, acc.: 64.45%] [Generator loss: 0.9385%]
# 4/4 [==============================] - 0s 3ms/step
# 280 [Discriminator loss: 0.6096%, acc.: 70.70%] [Generator loss: 0.9745%]
# 4/4 [==============================] - 0s 2ms/step
# 281 [Discriminator loss: 0.5906%, acc.: 70.70%] [Generator loss: 0.9446%]
# 4/4 [==============================] - 0s 3ms/step
# 282 [Discriminator loss: 0.6100%, acc.: 70.70%] [Generator loss: 0.9738%]
# 4/4 [==============================] - 0s 2ms/step
# 283 [Discriminator loss: 0.6128%, acc.: 68.75%] [Generator loss: 0.9643%]
# 4/4 [==============================] - 0s 4ms/step
# 284 [Discriminator loss: 0.6218%, acc.: 66.02%] [Generator loss: 0.9542%]
# 4/4 [==============================] - 0s 3ms/step
# 285 [Discriminator loss: 0.6846%, acc.: 58.59%] [Generator loss: 0.9793%]
# 4/4 [==============================] - 0s 2ms/step
# 286 [Discriminator loss: 0.6458%, acc.: 59.77%] [Generator loss: 0.9681%]
# 4/4 [==============================] - 0s 5ms/step
# 287 [Discriminator loss: 0.6320%, acc.: 63.67%] [Generator loss: 0.8946%]
# 4/4 [==============================] - 0s 2ms/step
# 288 [Discriminator loss: 0.6408%, acc.: 62.50%] [Generator loss: 0.9023%]
# 4/4 [==============================] - 0s 3ms/step
# 289 [Discriminator loss: 0.6109%, acc.: 66.80%] [Generator loss: 0.9946%]
# 4/4 [==============================] - 0s 2ms/step
# 290 [Discriminator loss: 0.6812%, acc.: 56.25%] [Generator loss: 0.9524%]
# 4/4 [==============================] - 0s 2ms/step
# 291 [Discriminator loss: 0.6464%, acc.: 58.98%] [Generator loss: 1.1620%]
# 4/4 [==============================] - 0s 3ms/step
# 292 [Discriminator loss: 0.7142%, acc.: 45.70%] [Generator loss: 0.9200%]
# 4/4 [==============================] - 0s 2ms/step
# 293 [Discriminator loss: 0.6402%, acc.: 57.03%] [Generator loss: 0.9546%]
# 4/4 [==============================] - 0s 3ms/step
# 294 [Discriminator loss: 0.6664%, acc.: 51.95%] [Generator loss: 0.9802%]
# 4/4 [==============================] - 0s 2ms/step
# 295 [Discriminator loss: 0.6760%, acc.: 52.34%] [Generator loss: 0.9201%]
# 4/4 [==============================] - 0s 2ms/step
# 296 [Discriminator loss: 0.6550%, acc.: 58.59%] [Generator loss: 0.9239%]
# 4/4 [==============================] - 0s 2ms/step
# 297 [Discriminator loss: 0.6402%, acc.: 62.11%] [Generator loss: 0.9701%]
# 4/4 [==============================] - 0s 2ms/step
# 298 [Discriminator loss: 0.6654%, acc.: 55.47%] [Generator loss: 0.9214%]
# 4/4 [==============================] - 0s 2ms/step
# 299 [Discriminator loss: 0.6251%, acc.: 60.55%] [Generator loss: 0.9482%]
# 4/4 [==============================] - 0s 2ms/step
# 300 [Discriminator loss: 0.6356%, acc.: 62.11%] [Generator loss: 0.9709%]
# 4/4 [==============================] - 0s 2ms/step
# 301 [Discriminator loss: 0.6398%, acc.: 61.33%] [Generator loss: 0.9277%]
# 4/4 [==============================] - 0s 2ms/step
# 302 [Discriminator loss: 0.6493%, acc.: 58.59%] [Generator loss: 0.9205%]
# 4/4 [==============================] - 0s 3ms/step
# 303 [Discriminator loss: 0.6469%, acc.: 60.94%] [Generator loss: 0.9244%]
# 4/4 [==============================] - 0s 2ms/step
# 304 [Discriminator loss: 0.6545%, acc.: 60.55%] [Generator loss: 0.9749%]
# 4/4 [==============================] - 0s 2ms/step
# 305 [Discriminator loss: 0.6696%, acc.: 59.77%] [Generator loss: 0.8818%]
# 4/4 [==============================] - 0s 2ms/step
# 306 [Discriminator loss: 0.6460%, acc.: 58.59%] [Generator loss: 0.8565%]
# 4/4 [==============================] - 0s 3ms/step
# 307 [Discriminator loss: 0.6630%, acc.: 57.03%] [Generator loss: 0.9650%]
# 4/4 [==============================] - 0s 3ms/step
# 308 [Discriminator loss: 0.6931%, acc.: 48.83%] [Generator loss: 0.8736%]
# 4/4 [==============================] - 0s 3ms/step
# 309 [Discriminator loss: 0.6610%, acc.: 56.64%] [Generator loss: 0.8833%]
# 4/4 [==============================] - 0s 3ms/step
# 310 [Discriminator loss: 0.6593%, acc.: 58.59%] [Generator loss: 0.8987%]
# 4/4 [==============================] - 0s 2ms/step
# 311 [Discriminator loss: 0.6451%, acc.: 60.94%] [Generator loss: 0.9321%]
# 4/4 [==============================] - 0s 2ms/step
# 312 [Discriminator loss: 0.6478%, acc.: 58.20%] [Generator loss: 0.9810%]
# 4/4 [==============================] - 0s 2ms/step
# 313 [Discriminator loss: 0.6677%, acc.: 54.69%] [Generator loss: 0.9217%]
# 4/4 [==============================] - 0s 5ms/step
# 314 [Discriminator loss: 0.6660%, acc.: 55.08%] [Generator loss: 0.9268%]
# 4/4 [==============================] - 0s 5ms/step
# 315 [Discriminator loss: 0.6525%, acc.: 60.55%] [Generator loss: 0.9854%]
# 4/4 [==============================] - 0s 4ms/step
# 316 [Discriminator loss: 0.6842%, acc.: 56.64%] [Generator loss: 0.9276%]
# 4/4 [==============================] - 0s 3ms/step
# 317 [Discriminator loss: 0.6455%, acc.: 60.55%] [Generator loss: 0.8872%]
# 4/4 [==============================] - 0s 2ms/step
# 318 [Discriminator loss: 0.6382%, acc.: 62.89%] [Generator loss: 0.8965%]
# 4/4 [==============================] - 0s 3ms/step
# 319 [Discriminator loss: 0.6346%, acc.: 64.45%] [Generator loss: 0.9463%]
# 4/4 [==============================] - 0s 2ms/step
# 320 [Discriminator loss: 0.6617%, acc.: 59.38%] [Generator loss: 0.9425%]
# 4/4 [==============================] - 0s 2ms/step
# 321 [Discriminator loss: 0.6230%, acc.: 67.97%] [Generator loss: 0.9168%]
# 4/4 [==============================] - 0s 2ms/step
# 322 [Discriminator loss: 0.6542%, acc.: 64.45%] [Generator loss: 0.9265%]
# 4/4 [==============================] - 0s 2ms/step
# 323 [Discriminator loss: 0.6386%, acc.: 62.50%] [Generator loss: 0.9694%]
# 4/4 [==============================] - 0s 2ms/step
# 324 [Discriminator loss: 0.6553%, acc.: 58.59%] [Generator loss: 0.9464%]
# 4/4 [==============================] - 0s 3ms/step
# 325 [Discriminator loss: 0.6450%, acc.: 63.28%] [Generator loss: 0.9410%]
# 4/4 [==============================] - 0s 3ms/step
# 326 [Discriminator loss: 0.6527%, acc.: 62.11%] [Generator loss: 0.8784%]
# 4/4 [==============================] - 0s 2ms/step
# 327 [Discriminator loss: 0.6351%, acc.: 63.67%] [Generator loss: 0.8879%]
# 4/4 [==============================] - 0s 2ms/step
# 328 [Discriminator loss: 0.6478%, acc.: 60.94%] [Generator loss: 0.9443%]
# 4/4 [==============================] - 0s 2ms/step
# 329 [Discriminator loss: 0.6551%, acc.: 62.11%] [Generator loss: 0.9258%]
# 4/4 [==============================] - 0s 2ms/step
# 330 [Discriminator loss: 0.6601%, acc.: 57.42%] [Generator loss: 0.8907%]
# 4/4 [==============================] - 0s 2ms/step
# 331 [Discriminator loss: 0.6414%, acc.: 64.84%] [Generator loss: 0.9401%]
# 4/4 [==============================] - 0s 2ms/step
# 332 [Discriminator loss: 0.6308%, acc.: 67.19%] [Generator loss: 0.9247%]
# 4/4 [==============================] - 0s 2ms/step
# 333 [Discriminator loss: 0.6231%, acc.: 66.80%] [Generator loss: 0.9484%]
# 4/4 [==============================] - 0s 2ms/step
# 334 [Discriminator loss: 0.6219%, acc.: 67.19%] [Generator loss: 0.9420%]
# 4/4 [==============================] - 0s 2ms/step
# 335 [Discriminator loss: 0.6394%, acc.: 66.41%] [Generator loss: 0.9123%]
# 4/4 [==============================] - 0s 2ms/step
# 336 [Discriminator loss: 0.6438%, acc.: 63.28%] [Generator loss: 0.9229%]
# 4/4 [==============================] - 0s 3ms/step
# 337 [Discriminator loss: 0.6383%, acc.: 64.06%] [Generator loss: 0.9766%]
# 4/4 [==============================] - 0s 2ms/step
# 338 [Discriminator loss: 0.6419%, acc.: 63.28%] [Generator loss: 0.9565%]
# 4/4 [==============================] - 0s 3ms/step
# 339 [Discriminator loss: 0.6391%, acc.: 63.67%] [Generator loss: 0.9440%]
# 4/4 [==============================] - 0s 2ms/step
# 340 [Discriminator loss: 0.6347%, acc.: 64.84%] [Generator loss: 0.9685%]
# 4/4 [==============================] - 0s 3ms/step
# 341 [Discriminator loss: 0.6554%, acc.: 59.77%] [Generator loss: 0.9971%]
# 4/4 [==============================] - 0s 2ms/step
# 342 [Discriminator loss: 0.6231%, acc.: 69.53%] [Generator loss: 0.9774%]
# 4/4 [==============================] - 0s 2ms/step
# 343 [Discriminator loss: 0.6073%, acc.: 67.19%] [Generator loss: 0.9754%]
# 4/4 [==============================] - 0s 2ms/step
# 344 [Discriminator loss: 0.6196%, acc.: 65.62%] [Generator loss: 1.0149%]
# 4/4 [==============================] - 0s 3ms/step
# 345 [Discriminator loss: 0.6183%, acc.: 64.84%] [Generator loss: 0.9813%]
# 4/4 [==============================] - 0s 3ms/step
# 346 [Discriminator loss: 0.6420%, acc.: 62.50%] [Generator loss: 0.9803%]
# 4/4 [==============================] - 0s 3ms/step
# 347 [Discriminator loss: 0.6459%, acc.: 63.28%] [Generator loss: 0.9601%]
# 4/4 [==============================] - 0s 3ms/step
# 348 [Discriminator loss: 0.6406%, acc.: 63.28%] [Generator loss: 0.9701%]
# 4/4 [==============================] - 0s 2ms/step
# ...
# 4/4 [==============================] - 0s 2ms/step
# 12717 [Discriminator loss: 0.7010%, acc.: 52.34%] [Generator loss: 0.7957%]
# 4/4 [==============================] - 0s 2ms/step
# 12718 [Discriminator loss: 0.6918%, acc.: 49.22%] [Generator loss: 0.7831%]
# 4/4 [==============================] - 0s 2ms/step
# 12719 [Discriminator loss: 0.6914%, acc.: 50.78%] [Generator loss: 0.7794%]
# 4/4 [==============================] - 0s 2ms/step
# 12720 [Discriminator loss: 0.6866%, acc.: 54.30%] [Generator loss: 0.7796%]
# 4/4 [==============================] - 0s 2ms/step
# 12721 [Discriminator loss: 0.6835%, acc.: 53.91%] [Generator loss: 0.7700%]
# 4/4 [==============================] - 0s 2ms/step
# 12722 [Discriminator loss: 0.7017%, acc.: 49.61%] [Generator loss: 0.7635%]
# 4/4 [==============================] - 0s 2ms/step
# 12723 [Discriminator loss: 0.6779%, acc.: 55.47%] [Generator loss: 0.7532%]
# 4/4 [==============================] - 0s 2ms/step
# 12724 [Discriminator loss: 0.6717%, acc.: 56.64%] [Generator loss: 0.7415%]
# 4/4 [==============================] - 0s 2ms/step
# 12725 [Discriminator loss: 0.6831%, acc.: 56.25%] [Generator loss: 0.7661%]
# 4/4 [==============================] - 0s 2ms/step
# 12726 [Discriminator loss: 0.7026%, acc.: 50.00%] [Generator loss: 0.7985%]
# 4/4 [==============================] - 0s 2ms/step
# 12727 [Discriminator loss: 0.6897%, acc.: 51.95%] [Generator loss: 0.7851%]
# 4/4 [==============================] - 0s 2ms/step
# 12728 [Discriminator loss: 0.6893%, acc.: 53.52%] [Generator loss: 0.7670%]
# 4/4 [==============================] - 0s 2ms/step
# 12729 [Discriminator loss: 0.6901%, acc.: 53.52%] [Generator loss: 0.7830%]
# 4/4 [==============================] - 0s 2ms/step
# 12730 [Discriminator loss: 0.6959%, acc.: 52.34%] [Generator loss: 0.7765%]
# 4/4 [==============================] - 0s 2ms/step
# 12731 [Discriminator loss: 0.6789%, acc.: 53.52%] [Generator loss: 0.7837%]
# 4/4 [==============================] - 0s 2ms/step
# 12732 [Discriminator loss: 0.7030%, acc.: 50.78%] [Generator loss: 0.7666%]
# 4/4 [==============================] - 0s 2ms/step
# 12733 [Discriminator loss: 0.6788%, acc.: 60.94%] [Generator loss: 0.7804%]
# 4/4 [==============================] - 0s 2ms/step
# 12734 [Discriminator loss: 0.6950%, acc.: 49.61%] [Generator loss: 0.7787%]
# 4/4 [==============================] - 0s 2ms/step
# 12735 [Discriminator loss: 0.6795%, acc.: 59.38%] [Generator loss: 0.7755%]
# 4/4 [==============================] - 0s 2ms/step
# 12736 [Discriminator loss: 0.6978%, acc.: 48.44%] [Generator loss: 0.7789%]
# 4/4 [==============================] - 0s 2ms/step
# 12737 [Discriminator loss: 0.6910%, acc.: 48.05%] [Generator loss: 0.7631%]
# 4/4 [==============================] - 0s 2ms/step
# 12738 [Discriminator loss: 0.6835%, acc.: 56.25%] [Generator loss: 0.7704%]
# 4/4 [==============================] - 0s 2ms/step
# 12739 [Discriminator loss: 0.6797%, acc.: 57.42%] [Generator loss: 0.7944%]
# 4/4 [==============================] - 0s 2ms/step
# 12740 [Discriminator loss: 0.6943%, acc.: 51.95%] [Generator loss: 0.8043%]
# 4/4 [==============================] - 0s 2ms/step
# 12741 [Discriminator loss: 0.6901%, acc.: 49.61%] [Generator loss: 0.7825%]
# 4/4 [==============================] - 0s 2ms/step
# 12742 [Discriminator loss: 0.6749%, acc.: 56.25%] [Generator loss: 0.7652%]
# 4/4 [==============================] - 0s 2ms/step
# 12743 [Discriminator loss: 0.6893%, acc.: 53.91%] [Generator loss: 0.7599%]
# 4/4 [==============================] - 0s 2ms/step
# 12744 [Discriminator loss: 0.6871%, acc.: 54.30%] [Generator loss: 0.7932%]
# 4/4 [==============================] - 0s 2ms/step
# 12745 [Discriminator loss: 0.6899%, acc.: 55.47%] [Generator loss: 0.7712%]
# 4/4 [==============================] - 0s 2ms/step
# 12746 [Discriminator loss: 0.6830%, acc.: 57.03%] [Generator loss: 0.7977%]
# 4/4 [==============================] - 0s 2ms/step
# 12747 [Discriminator loss: 0.6975%, acc.: 49.61%] [Generator loss: 0.7871%]
# 4/4 [==============================] - 0s 2ms/step
# 12748 [Discriminator loss: 0.6998%, acc.: 50.00%] [Generator loss: 0.7690%]
# 4/4 [==============================] - 0s 2ms/step
# 12749 [Discriminator loss: 0.6827%, acc.: 51.95%] [Generator loss: 0.8151%]
# 4/4 [==============================] - 0s 2ms/step
# 12750 [Discriminator loss: 0.6974%, acc.: 53.91%] [Generator loss: 0.7722%]
# 4/4 [==============================] - 0s 2ms/step
# 12751 [Discriminator loss: 0.6893%, acc.: 54.30%] [Generator loss: 0.7730%]
# 4/4 [==============================] - 0s 2ms/step
# 12752 [Discriminator loss: 0.6876%, acc.: 54.30%] [Generator loss: 0.7815%]
# 4/4 [==============================] - 0s 2ms/step
# 12753 [Discriminator loss: 0.6833%, acc.: 55.08%] [Generator loss: 0.7568%]
# 4/4 [==============================] - 0s 2ms/step
# 12754 [Discriminator loss: 0.6755%, acc.: 57.03%] [Generator loss: 0.7637%]
# 4/4 [==============================] - 0s 2ms/step
# 12755 [Discriminator loss: 0.6909%, acc.: 52.73%] [Generator loss: 0.7594%]
# 4/4 [==============================] - 0s 2ms/step
# 12756 [Discriminator loss: 0.6823%, acc.: 55.86%] [Generator loss: 0.7764%]
# 4/4 [==============================] - 0s 2ms/step
# 12757 [Discriminator loss: 0.6819%, acc.: 59.77%] [Generator loss: 0.7998%]
# 4/4 [==============================] - 0s 2ms/step
# 12758 [Discriminator loss: 0.7004%, acc.: 48.83%] [Generator loss: 0.7781%]
# 4/4 [==============================] - 0s 2ms/step
# 12759 [Discriminator loss: 0.6736%, acc.: 57.81%] [Generator loss: 0.7918%]
# 4/4 [==============================] - 0s 3ms/step
# 12760 [Discriminator loss: 0.6929%, acc.: 52.73%] [Generator loss: 0.7623%]
# 4/4 [==============================] - 0s 2ms/step
# 12761 [Discriminator loss: 0.6838%, acc.: 55.86%] [Generator loss: 0.7699%]
# 4/4 [==============================] - 0s 2ms/step
# 12762 [Discriminator loss: 0.6857%, acc.: 57.81%] [Generator loss: 0.7683%]
# 4/4 [==============================] - 0s 2ms/step
# 12763 [Discriminator loss: 0.6805%, acc.: 58.20%] [Generator loss: 0.7669%]
# 4/4 [==============================] - 0s 2ms/step
# 12764 [Discriminator loss: 0.7155%, acc.: 47.27%] [Generator loss: 0.7680%]
# 4/4 [==============================] - 0s 2ms/step
# 12765 [Discriminator loss: 0.6706%, acc.: 60.55%] [Generator loss: 0.7991%]
# 4/4 [==============================] - 0s 2ms/step
# 12766 [Discriminator loss: 0.6906%, acc.: 50.78%] [Generator loss: 0.7931%]
# 4/4 [==============================] - 0s 2ms/step
# 12767 [Discriminator loss: 0.6942%, acc.: 53.52%] [Generator loss: 0.7669%]
# 4/4 [==============================] - 0s 2ms/step
# 12768 [Discriminator loss: 0.6883%, acc.: 52.73%] [Generator loss: 0.7984%]
# 4/4 [==============================] - 0s 2ms/step
# 12769 [Discriminator loss: 0.6873%, acc.: 52.73%] [Generator loss: 0.7907%]
# 4/4 [==============================] - 0s 2ms/step
# 12770 [Discriminator loss: 0.6862%, acc.: 56.25%] [Generator loss: 0.8239%]
# 4/4 [==============================] - 0s 2ms/step
# 12771 [Discriminator loss: 0.7056%, acc.: 51.95%] [Generator loss: 0.7912%]
# 4/4 [==============================] - 0s 2ms/step
# 12772 [Discriminator loss: 0.6901%, acc.: 53.52%] [Generator loss: 0.7776%]
# 4/4 [==============================] - 0s 3ms/step
# 12773 [Discriminator loss: 0.6804%, acc.: 53.12%] [Generator loss: 0.7717%]
# 4/4 [==============================] - 0s 2ms/step
# 12774 [Discriminator loss: 0.6963%, acc.: 51.95%] [Generator loss: 0.7612%]
# 4/4 [==============================] - 0s 2ms/step
# 12775 [Discriminator loss: 0.7015%, acc.: 51.56%] [Generator loss: 0.7564%]
# 4/4 [==============================] - 0s 2ms/step
# 12776 [Discriminator loss: 0.6887%, acc.: 51.56%] [Generator loss: 0.7785%]
# 4/4 [==============================] - 0s 2ms/step
# 12777 [Discriminator loss: 0.6890%, acc.: 52.73%] [Generator loss: 0.7654%]
# 4/4 [==============================] - 0s 2ms/step
# 12778 [Discriminator loss: 0.6926%, acc.: 50.78%] [Generator loss: 0.7679%]
# 4/4 [==============================] - 0s 2ms/step
# 12779 [Discriminator loss: 0.6794%, acc.: 58.20%] [Generator loss: 0.7759%]
# 4/4 [==============================] - 0s 2ms/step
# 12780 [Discriminator loss: 0.6923%, acc.: 48.83%] [Generator loss: 0.7830%]
# 4/4 [==============================] - 0s 2ms/step
# 12781 [Discriminator loss: 0.6781%, acc.: 55.86%] [Generator loss: 0.7672%]
# 4/4 [==============================] - 0s 2ms/step
# 12782 [Discriminator loss: 0.6931%, acc.: 52.73%] [Generator loss: 0.7657%]
# 4/4 [==============================] - 0s 2ms/step
# 12783 [Discriminator loss: 0.6768%, acc.: 57.03%] [Generator loss: 0.7876%]
# 4/4 [==============================] - 0s 2ms/step
# 12784 [Discriminator loss: 0.6665%, acc.: 62.89%] [Generator loss: 0.7499%]
# 4/4 [==============================] - 0s 2ms/step
# 12785 [Discriminator loss: 0.6923%, acc.: 55.47%] [Generator loss: 0.7761%]
# 4/4 [==============================] - 0s 2ms/step
# 12786 [Discriminator loss: 0.7001%, acc.: 55.08%] [Generator loss: 0.7809%]
# 4/4 [==============================] - 0s 2ms/step
# 12787 [Discriminator loss: 0.6653%, acc.: 60.16%] [Generator loss: 0.7813%]
# 4/4 [==============================] - 0s 2ms/step
# 12788 [Discriminator loss: 0.6965%, acc.: 51.95%] [Generator loss: 0.7689%]
# 4/4 [==============================] - 0s 2ms/step
# 12789 [Discriminator loss: 0.6839%, acc.: 55.08%] [Generator loss: 0.7649%]
# 4/4 [==============================] - 0s 2ms/step
# 12790 [Discriminator loss: 0.6796%, acc.: 57.03%] [Generator loss: 0.7601%]
# 4/4 [==============================] - 0s 2ms/step
# 12791 [Discriminator loss: 0.6914%, acc.: 51.17%] [Generator loss: 0.7803%]
# 4/4 [==============================] - 0s 2ms/step
# 12792 [Discriminator loss: 0.6868%, acc.: 50.78%] [Generator loss: 0.7654%]
# 4/4 [==============================] - 0s 2ms/step
# 12793 [Discriminator loss: 0.6872%, acc.: 50.78%] [Generator loss: 0.7646%]
# 4/4 [==============================] - 0s 2ms/step
# 12794 [Discriminator loss: 0.6823%, acc.: 57.03%] [Generator loss: 0.7912%]
# 4/4 [==============================] - 0s 2ms/step
# 12795 [Discriminator loss: 0.6913%, acc.: 55.08%] [Generator loss: 0.7454%]
# 4/4 [==============================] - 0s 2ms/step
# 12796 [Discriminator loss: 0.6630%, acc.: 62.50%] [Generator loss: 0.7505%]
# 4/4 [==============================] - 0s 2ms/step
# 12797 [Discriminator loss: 0.6767%, acc.: 58.20%] [Generator loss: 0.7800%]
# 4/4 [==============================] - 0s 2ms/step
# 12798 [Discriminator loss: 0.7125%, acc.: 48.05%] [Generator loss: 0.7389%]
# 4/4 [==============================] - 0s 2ms/step
# 12799 [Discriminator loss: 0.6854%, acc.: 53.91%] [Generator loss: 0.7528%]
# 4/4 [==============================] - 0s 2ms/step
# 12800 [Discriminator loss: 0.6795%, acc.: 60.55%] [Generator loss: 0.7584%]
# 4/4 [==============================] - 0s 2ms/step
# 12801 [Discriminator loss: 0.6990%, acc.: 49.61%] [Generator loss: 0.7485%]
# 4/4 [==============================] - 0s 2ms/step
# 12802 [Discriminator loss: 0.6844%, acc.: 51.95%] [Generator loss: 0.7570%]
# 4/4 [==============================] - 0s 2ms/step
# 12803 [Discriminator loss: 0.6853%, acc.: 56.64%] [Generator loss: 0.7371%]
# 4/4 [==============================] - 0s 2ms/step
# 12804 [Discriminator loss: 0.6927%, acc.: 53.52%] [Generator loss: 0.7469%]
# 4/4 [==============================] - 0s 2ms/step
# 12805 [Discriminator loss: 0.6840%, acc.: 55.47%] [Generator loss: 0.7565%]
# 4/4 [==============================] - 0s 2ms/step
# 12806 [Discriminator loss: 0.6785%, acc.: 55.86%] [Generator loss: 0.7517%]
# 4/4 [==============================] - 0s 2ms/step
# 12807 [Discriminator loss: 0.6863%, acc.: 51.95%] [Generator loss: 0.7615%]
# 4/4 [==============================] - 0s 2ms/step
# 12808 [Discriminator loss: 0.6867%, acc.: 53.91%] [Generator loss: 0.7662%]
# 4/4 [==============================] - 0s 2ms/step
# 12809 [Discriminator loss: 0.6913%, acc.: 49.61%] [Generator loss: 0.7957%]
# 4/4 [==============================] - 0s 2ms/step
# 12810 [Discriminator loss: 0.6864%, acc.: 52.34%] [Generator loss: 0.7818%]
# 4/4 [==============================] - 0s 2ms/step
# 12811 [Discriminator loss: 0.6939%, acc.: 52.34%] [Generator loss: 0.7615%]
# 4/4 [==============================] - 0s 2ms/step
# 12812 [Discriminator loss: 0.6866%, acc.: 55.08%] [Generator loss: 0.7632%]
# 4/4 [==============================] - 0s 2ms/step
# 12813 [Discriminator loss: 0.6865%, acc.: 52.73%] [Generator loss: 0.7761%]
# 4/4 [==============================] - 0s 2ms/step
# 12814 [Discriminator loss: 0.6823%, acc.: 52.34%] [Generator loss: 0.7888%]
# 4/4 [==============================] - 0s 2ms/step
# 12815 [Discriminator loss: 0.6925%, acc.: 53.52%] [Generator loss: 0.7618%]
# 4/4 [==============================] - 0s 2ms/step
# 12816 [Discriminator loss: 0.7064%, acc.: 49.61%] [Generator loss: 0.7736%]
# 4/4 [==============================] - 0s 2ms/step
# 12817 [Discriminator loss: 0.6848%, acc.: 54.30%] [Generator loss: 0.7674%]
# 4/4 [==============================] - 0s 2ms/step
# 12818 [Discriminator loss: 0.6764%, acc.: 61.33%] [Generator loss: 0.7774%]
# 4/4 [==============================] - 0s 2ms/step
# 12819 [Discriminator loss: 0.6976%, acc.: 50.78%] [Generator loss: 0.7882%]
# 4/4 [==============================] - 0s 2ms/step
# 12820 [Discriminator loss: 0.6894%, acc.: 52.73%] [Generator loss: 0.7740%]
# 4/4 [==============================] - 0s 2ms/step
# 12821 [Discriminator loss: 0.7018%, acc.: 43.75%] [Generator loss: 0.8062%]
# 4/4 [==============================] - 0s 2ms/step
# 12822 [Discriminator loss: 0.6905%, acc.: 53.91%] [Generator loss: 0.7620%]
# 4/4 [==============================] - 0s 2ms/step
# 12823 [Discriminator loss: 0.6978%, acc.: 51.56%] [Generator loss: 0.7901%]
# 4/4 [==============================] - 0s 2ms/step
# 12824 [Discriminator loss: 0.6953%, acc.: 51.17%] [Generator loss: 0.7890%]
# 4/4 [==============================] - 0s 2ms/step
# 12825 [Discriminator loss: 0.6975%, acc.: 52.73%] [Generator loss: 0.7820%]
# 4/4 [==============================] - 0s 2ms/step
# 12826 [Discriminator loss: 0.6976%, acc.: 47.66%] [Generator loss: 0.7560%]
# 4/4 [==============================] - 0s 2ms/step
# 12827 [Discriminator loss: 0.7050%, acc.: 51.95%] [Generator loss: 0.7678%]
# 4/4 [==============================] - 0s 2ms/step
# 12828 [Discriminator loss: 0.6863%, acc.: 55.08%] [Generator loss: 0.7751%]
# 4/4 [==============================] - 0s 2ms/step
# 12829 [Discriminator loss: 0.6967%, acc.: 50.78%] [Generator loss: 0.7661%]
# 4/4 [==============================] - 0s 2ms/step
# 12830 [Discriminator loss: 0.6868%, acc.: 51.95%] [Generator loss: 0.7754%]
# 4/4 [==============================] - 0s 2ms/step
# 12831 [Discriminator loss: 0.6921%, acc.: 51.56%] [Generator loss: 0.7675%]
# 4/4 [==============================] - 0s 2ms/step
# 12832 [Discriminator loss: 0.6914%, acc.: 50.39%] [Generator loss: 0.7697%]
# 4/4 [==============================] - 0s 2ms/step
# 12833 [Discriminator loss: 0.6798%, acc.: 57.42%] [Generator loss: 0.7827%]
# 4/4 [==============================] - 0s 2ms/step
# 12834 [Discriminator loss: 0.6966%, acc.: 48.83%] [Generator loss: 0.7647%]
# 4/4 [==============================] - 0s 2ms/step
# 12835 [Discriminator loss: 0.6830%, acc.: 57.03%] [Generator loss: 0.7752%]
# 4/4 [==============================] - 0s 2ms/step
# 12836 [Discriminator loss: 0.7016%, acc.: 51.17%] [Generator loss: 0.7594%]
# 4/4 [==============================] - 0s 2ms/step
# 12837 [Discriminator loss: 0.6758%, acc.: 54.69%] [Generator loss: 0.7771%]
# 4/4 [==============================] - 0s 2ms/step
# 12838 [Discriminator loss: 0.7001%, acc.: 48.83%] [Generator loss: 0.7760%]
# 4/4 [==============================] - 0s 2ms/step
# 12839 [Discriminator loss: 0.6786%, acc.: 55.08%] [Generator loss: 0.7907%]
# 4/4 [==============================] - 0s 2ms/step
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
